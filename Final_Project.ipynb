# %%
import os
import cv2
import mediapipe as mp
import numpy as np
import time

# Gender selection
gender = input("Select Gender (male/female): ").strip().lower()
if gender not in ['male', 'female']:
    print("Invalid gender selection.")
    exit(1)

# Initialize MediaPipe Pose and Hands
mp_pose = mp.solutions.pose
mp_hands = mp.solutions.hands
pose = mp_pose.Pose(static_image_mode=False, model_complexity=1, enable_segmentation=False, min_detection_confidence=0.5)
hands = mp_hands.Hands(static_image_mode=False, max_num_hands=2, min_detection_confidence=0.78)

# Helper function to overlay PNG images
def overlay_png(image, overlay, position):
    if overlay.shape[2] == 3:  # If the overlay does not have an alpha channel
        overlay = np.dstack((overlay, np.ones((overlay.shape[0], overlay.shape[1]), dtype="uint8") * 255))
    
    y_offset, x_offset = map(int, position)  # Ensure offsets are integers
    y1, y2 = y_offset, y_offset + overlay.shape[0]
    x1, x2 = x_offset, x_offset + overlay.shape[1]

    # Ensure overlay does not exceed image boundaries
    if y1 < 0: y1 = 0
    if y2 > image.shape[0]: y2 = image.shape[0]
    if x1 < 0: x1 = 0
    if x2 > image.shape[1]: x2 = image.shape[1]

    overlay_resized = overlay[0:y2-y1, 0:x2-x1]

    alpha_s = overlay_resized[:, :, 3] / 255.0
    alpha_l = 1.0 - alpha_s

    for c in range(0, 3):
        image[y1:y2, x1:x2, c] = (alpha_s * overlay_resized[:, :, c] + alpha_l * image[y1:y2, x1:x2, c])

    return image

# Category paths
categories = ["casual", "formal", "summer", "winter"]
category_buttons = ["casual.png", "formal.png", "summer.png", "winter.png"]
category_folder_path = f"{gender}/"

# Initialize video capture from camera
cap = cv2.VideoCapture(0)

# Set the window size
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1200)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)
cap.set(cv2.CAP_PROP_FPS, 30)

# Load category buttons
category_button_images = []
for button in category_buttons:
    button_path = f"Category_buttons/{button}"
    button_img = cv2.imread(button_path, cv2.IMREAD_UNCHANGED)
    if button_img is not None:
        button_img = cv2.resize(button_img, (180, 100))
        category_button_images.append(button_img)
    else:
        print(f"Failed to load button image: {button_path}")

category_selected = False

while True:
    success, img = cap.read()
    if not success:
        print("Failed to read from camera.")
        break

    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results_hands = hands.process(img_rgb)

    if not category_selected:
        if results_hands.multi_hand_landmarks:
            for hand_landmarks in results_hands.multi_hand_landmarks:
                hand_landmarks_x = [lm.x * img.shape[1] for lm in hand_landmarks.landmark]
                hand_landmarks_y = [lm.y * img.shape[0] for lm in hand_landmarks.landmark]

                # Check for category selection
                for i, button_img in enumerate(category_button_images):
                    if i < 2:
                        # Left side buttons (casual, formal)
                        x_pos = 50
                        y_pos = 100 + i * 150
                    else:
                        # Right side buttons (summer, winter)
                        x_pos = img.shape[1] - 150
                        y_pos = 100 + (i - 2) * 150

                    if (x_pos < hand_landmarks_x[8] < x_pos + 100 and
                            y_pos < hand_landmarks_y[8] < y_pos + 100):
                        selected_category = categories[i]
                        category_folder_path = f"{gender}/{selected_category}/"
                        category_selected = True
                        print(f"Selected category: {selected_category}")
                        break

                if category_selected:
                    break

        # Display category buttons
        for i, button_img in enumerate(category_button_images):
            if i < 2:
                x_pos = 50
                y_pos = 100 + i * 150
            else:
                x_pos = img.shape[1] - 180
                y_pos = 100 + (i - 2) * 150
            img = overlay_png(img, button_img, (y_pos, x_pos))

        cv2.imshow("Image", img)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

        if not category_selected:
            continue

    shirtFolderPath = category_folder_path
    if not os.path.exists(shirtFolderPath):
        print(f"Shirt folder path '{shirtFolderPath}' does not exist.")
        category_selected = False
        continue

    # Filter to get only valid image files
    valid_image_extensions = [".png", ".jpg", ".jpeg"]
    listShirts = [f for f in os.listdir(shirtFolderPath) if os.path.splitext(f)[1].lower() in valid_image_extensions]

    if len(listShirts) == 0:
        print(f"No valid shirt images found in the directory '{shirtFolderPath}'.")
        category_selected = False
        continue

    print(f"Found {len(listShirts)} valid shirts in the directory '{shirtFolderPath}'.")

    fixedRatio = 370 / 200  # widthOfShirt/widthOfPoint11to12
    shirtRatioHeightWidth = 581 / 440
    imageNumber = 0

    # Thumbnail settings
    thumbnail_width = 100
    thumbnail_height = int(thumbnail_width * shirtRatioHeightWidth)
    thumbnail_gap = 20
    thumbnails = []

    # Load thumbnails
    for shirt in listShirts:
        imgShirtPath = os.path.join(shirtFolderPath, shirt)
        imgShirt = cv2.imread(imgShirtPath, cv2.IMREAD_UNCHANGED)
        if imgShirt is not None:
            imgShirtThumbnail = cv2.resize(imgShirt, (thumbnail_width, thumbnail_height))
            thumbnails.append(imgShirtThumbnail)

    # Load buttons
    exit_button = cv2.imread("button/exit-button-icon-18.png", cv2.IMREAD_UNCHANGED)
    picture_click_button = cv2.imread("button/pngtree-blue-camera-button-cirlce-png-image_4255760-removebg-preview.png", cv2.IMREAD_UNCHANGED)
    back_button = cv2.imread("button/button.png", cv2.IMREAD_UNCHANGED)  # Assume you have a back button image
    button_size = 100

    # Resize buttons
    exit_button = cv2.resize(exit_button, (button_size, button_size))
    picture_click_button = cv2.resize(picture_click_button, (button_size, button_size))
    back_button = cv2.resize(back_button, (button_size, button_size))

    selected_shirt_index = 0
    scroll_offset = 0
    scroll_velocity = 0
    scroll_friction = 0.9
    select_timer = 0
    selection_delay = 2  # Seconds required to select a shirt
    last_picture_time = 0

    # Path for saving pictures
    picture_save_path = "shirts/pictures"
    os.makedirs(picture_save_path, exist_ok=True)

    while True:
        success, img = cap.read()
        if not success:
            print("Failed to read from camera.")
            break

        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        results_pose = pose.process(img_rgb)
        results_hands = hands.process(img_rgb)

        current_time = time.time()

        if results_pose.pose_landmarks:
            lmList = results_pose.pose_landmarks.landmark
            lm11 = [int(lmList[11].x * img.shape[1]), int(lmList[11].y * img.shape[0])]
            lm12 = [int(lmList[12].x * img.shape[1]), int(lmList[12].y * img.shape[0])]
            lm23 = [int(lmList[23].x * img.shape[1]), int(lmList[23].y * img.shape[0])]
            # Debugging pose landmarks
            print(f"lm23: {lm23}, lm11: {lm11}, lm12: {lm12}")

            widthOfShirt = int((lm11[0] - lm12[0]) * fixedRatio)
            
            if widthOfShirt > 0:  # Ensure the width is positive
                try:
                    imgShirtPath = os.path.join(shirtFolderPath, listShirts[selected_shirt_index])
                    print(f"Loading shirt image from path: {imgShirtPath}")
                    imgShirt = cv2.imread(imgShirtPath, cv2.IMREAD_UNCHANGED)
                    if imgShirt is not None:
                        imgShirt = cv2.resize(imgShirt, (widthOfShirt, int(widthOfShirt * shirtRatioHeightWidth)))
                        currentScale = widthOfShirt / imgShirt.shape[1]
                        # Calculate the midpoint between lm11 and lm12
                        midpoint_x = (lm11[0] + lm12[0]) // 2
                        midpoint_y = (lm11[1] + lm12[1]) // 2
                        
                        # Calculate the position to place the shirt overlay
                        x_offset = midpoint_x - (imgShirt.shape[1] // 2)
                        y_offset = lm11[1] - 110 # Adjust as needed to position the shirt correctly vertically
                        
                        # Debugging shirt overlay position
                        print(f"Shirt Position: (x: {x_offset}, y: {y_offset}), Size: {imgShirt.shape}")
                        
                        # Overlay the shirt on the image
                        img = overlay_png(img, imgShirt, (y_offset, x_offset))
                    else:
                        print(f"Failed to load shirt image: {imgShirtPath}")
                except Exception as e:
                    print(f"Error loading or resizing shirt image: {e}")
                    pass

        if results_hands.multi_hand_landmarks:
            for hand_landmarks in results_hands.multi_hand_landmarks:
                hand_landmarks_x = [lm.x * img.shape[1] for lm in hand_landmarks.landmark]
                hand_landmarks_y = [lm.y * img.shape[0] for lm in hand_landmarks.landmark]

                # Debugging hand landmark coordinates
                print(f"Hand Landmark X: {hand_landmarks_x}")
                print(f"Hand Landmark Y: {hand_landmarks_y}")

                # Check if hand is selecting a thumbnail
                selecting = False
                for i, thumbnail in enumerate(thumbnails):
                    y_position = thumbnail_gap + i * (thumbnail_height + thumbnail_gap) - scroll_offset
                    if (thumbnail_gap < hand_landmarks_x[8] < thumbnail_gap + thumbnail_width and
                            y_position < hand_landmarks_y[8] < y_position + thumbnail_height):
                        selecting = True
                        if select_timer == 0:
                            select_timer = current_time
                        elif current_time - select_timer >= selection_delay:
                            selected_shirt_index = i
                            print(f"Selected shirt index: {selected_shirt_index}")
                            select_timer = 0  # Reset the timer after selection
                        break

                if not selecting:
                    select_timer = 0  # Reset timer if not selecting

                # Draw selection progress bar
                if selecting:
                    progress_length = int((current_time - select_timer) / selection_delay * thumbnail_width)
                    progress_length = max(0, min(progress_length, thumbnail_width))  # Ensure progress_length is within valid bounds
                    cv2.rectangle(img, (thumbnail_gap, img.shape[0] - 30), 
                                  (thumbnail_gap + progress_length, img.shape[0] - 10), 
                                  (0, 255, 0), -1)
                # Check for scrolling gesture
                if hand_landmarks_x[8] < thumbnail_gap:
                    # Calculate the desired scroll offset based on hand position
                    desired_scroll = (len(thumbnails) * (thumbnail_height + thumbnail_gap) - img.shape[0]) * (hand_landmarks_y[8] / img.shape[0])
                    scroll_velocity += (desired_scroll - scroll_offset) * 0.05  # Update scroll velocity based on hand position

                # Check for exit gesture
                if (img.shape[1] - button_size < hand_landmarks_x[8] < img.shape[1] and
                        0 < hand_landmarks_y[8] < button_size):
                    cap.release()
                    cv2.destroyAllWindows()
                    exit()
                    
                # Check for back gesture
                if (img.shape[0] - button_size < hand_landmarks_y[8] < img.shape[0] and
                        img.shape[1] - button_size < hand_landmarks_x[8] < img.shape[1]):
                    print("Back button clicked.")
                    category_selected = False
                    break

                # Check for picture click gesture
                if (img.shape[1] - button_size < hand_landmarks_x[8] < img.shape[1] and
                        img.shape[0] // 2 - button_size // 2 < hand_landmarks_y[8] < img.shape[0] // 2 + button_size // 2):
                    if current_time - last_picture_time > 1:  # Avoid multiple pictures in quick succession
                        picture_name = f"shirt_{int(current_time)}.png"
                        picture_path = os.path.join(picture_save_path, picture_name)
                        cv2.imwrite(picture_path, img)
                        print(f"Picture saved: {picture_path}")
                        last_picture_time = current_time
                        # Blink effect
                        img = np.zeros_like(img)
                        cv2.imshow("Image", img)
                        cv2.waitKey(100)

        if not category_selected:
            # Break the loop to go back to category selection screen
            break

        # Apply scroll velocity and friction
        scroll_offset += scroll_velocity
        scroll_velocity *= scroll_friction

        # Ensure scroll_offset does not exceed the boundaries
        max_scroll_offset = max(0, len(thumbnails) * (thumbnail_height + thumbnail_gap) - img.shape[0])
        scroll_offset = min(max(scroll_offset, 0), max_scroll_offset)

        # Display thumbnails on the left side of the camera feed
        for i, thumbnail in enumerate(thumbnails):
            y_position = int(thumbnail_gap + i * (thumbnail_height + thumbnail_gap) - scroll_offset)
            if 0 <= y_position + thumbnail_height < img.shape[0]:  # Ensure thumbnail fits within image bounds
                img = overlay_png(img, thumbnail, (y_position, thumbnail_gap))

        # Overlay buttons
        img = overlay_png(img, exit_button, (0, img.shape[1] - button_size))
        img = overlay_png(img, picture_click_button, (img.shape[0] // 2 - button_size // 2, img.shape[1] - button_size))
        img = overlay_png(img, back_button, (img.shape[0] - button_size, img.shape[1] - button_size))

        cv2.imshow("Image", img)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# Select Gender (male/female):  male
# C:\Users\AJ\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# Selected category: formal
# Found 4 valid shirts in the directory 'male/formal/'.
# lm23: [795, 1386], lm11: [851, 715], lm12: [363, 706]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 156, y: 605), Size: (1191, 902, 4)
# Hand Landmark X: [110.83662986755371, 186.0453987121582, 232.3581314086914, 256.71260833740234, 259.3776321411133, 156.4858913421631, 155.7573127746582, 151.25537872314453, 144.45284843444824, 122.42669105529785, 124.5429801940918, 123.41094970703125, 120.64615249633789, 86.60076141357422, 92.56912231445312, 98.19202423095703, 101.58761024475098, 48.030290603637695, 55.64692974090576, 64.2253589630127, 74.31084632873535]
# Hand Landmark Y: [658.551836013794, 608.2395172119141, 527.7015781402588, 464.66726303100586, 414.2470979690552, 445.1424551010132, 366.49184703826904, 316.9021797180176, 275.0900602340698, 442.09529399871826, 354.169864654541, 296.42396450042725, 248.59957695007324, 447.16694355010986, 362.7867078781128, 310.6294584274292, 267.95190811157227, 460.04077434539795, 391.7286014556885, 348.58808040618896, 308.880250453949]
# lm23: [809, 1358], lm11: [860, 719], lm12: [402, 701]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 208, y: 609), Size: (1118, 847, 4)
# Hand Landmark X: [265.9237480163574, 338.10577392578125, 390.750732421875, 427.5441360473633, 450.0978088378906, 341.0050582885742, 397.0711898803711, 443.2035446166992, 464.1661071777344, 314.53954696655273, 378.3112335205078, 429.51316833496094, 449.06219482421875, 288.0628776550293, 353.8622283935547, 397.70565032958984, 410.3853988647461, 261.16188049316406, 318.06774139404297, 355.8526611328125, 370.4884338378906]
# Hand Landmark Y: [784.6098232269287, 737.4528121948242, 674.2737007141113, 624.6751499176025, 586.8960428237915, 579.290885925293, 524.9805736541748, 550.9854698181152, 590.542688369751, 582.72385597229, 533.2854223251343, 567.3018836975098, 611.0338640213013, 595.336332321167, 558.6362886428833, 597.017412185669, 639.3744277954102, 617.0711517333984, 589.890546798706, 612.0852041244507, 644.1482877731323]
# lm23: [806, 1353], lm11: [860, 718], lm12: [396, 705]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 199, y: 608), Size: (1132, 858, 4)
# lm23: [798, 1355], lm11: [861, 718], lm12: [394, 709]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 196, y: 608), Size: (1139, 863, 4)
# lm23: [798, 1354], lm11: [866, 715], lm12: [390, 707]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 188, y: 605), Size: (1162, 880, 4)
# lm23: [798, 1355], lm11: [867, 715], lm12: [390, 707]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 187, y: 605), Size: (1164, 882, 4)
# lm23: [796, 1355], lm11: [871, 711], lm12: [381, 704]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 173, y: 601), Size: (1196, 906, 4)
# lm23: [796, 1354], lm11: [871, 709], lm12: [376, 704]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 166, y: 599), Size: (1208, 915, 4)
# lm23: [796, 1353], lm11: [871, 706], lm12: [373, 703]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 162, y: 596), Size: (1216, 921, 4)
# lm23: [803, 1352], lm11: [877, 703], lm12: [373, 700]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 159, y: 593), Size: (1230, 932, 4)
# lm23: [803, 1354], lm11: [880, 699], lm12: [370, 696]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 154, y: 589), Size: (1245, 943, 4)
# lm23: [809, 1353], lm11: [885, 683], lm12: [368, 680]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 148, y: 573), Size: (1262, 956, 4)
# lm23: [811, 1340], lm11: [917, 648], lm12: [366, 632]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 132, y: 538), Size: (1345, 1019, 4)
# lm23: [813, 1309], lm11: [934, 604], lm12: [366, 580]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 125, y: 494), Size: (1386, 1050, 4)
# lm23: [811, 1241], lm11: [940, 529], lm12: [366, 498]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 123, y: 419), Size: (1401, 1061, 4)
# lm23: [804, 1265], lm11: [936, 572], lm12: [355, 546]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 108, y: 462), Size: (1418, 1074, 4)
# lm23: [768, 1240], lm11: [910, 540], lm12: [355, 518]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 119, y: 430), Size: (1354, 1026, 4)
# lm23: [764, 1240], lm11: [904, 529], lm12: [355, 501]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 122, y: 419), Size: (1340, 1015, 4)
# lm23: [767, 1224], lm11: [902, 507], lm12: [357, 490]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 125, y: 397), Size: (1331, 1008, 4)
# lm23: [770, 1228], lm11: [902, 527], lm12: [356, 510]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 124, y: 417), Size: (1333, 1010, 4)
# lm23: [771, 1225], lm11: [885, 559], lm12: [357, 562]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 133, y: 449), Size: (1288, 976, 4)
# lm23: [773, 1222], lm11: [855, 560], lm12: [350, 579]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 135, y: 450), Size: (1233, 934, 4)
# lm23: [774, 1214], lm11: [839, 561], lm12: [344, 585]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 134, y: 451), Size: (1208, 915, 4)
# lm23: [768, 1215], lm11: [816, 563], lm12: [325, 593]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 116, y: 453), Size: (1198, 908, 4)
# lm23: [758, 1210], lm11: [817, 565], lm12: [315, 594]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 102, y: 455), Size: (1225, 928, 4)
# lm23: [743, 1206], lm11: [803, 564], lm12: [295, 593]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 80, y: 454), Size: (1239, 939, 4)
# lm23: [648, 1209], lm11: [738, 564], lm12: [212, 590]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: -11, y: 454), Size: (1284, 973, 4)
# lm23: [625, 1214], lm11: [706, 565], lm12: [171, 589]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: -56, y: 455), Size: (1305, 989, 4)
# lm23: [647, 1215], lm11: [710, 566], lm12: [192, 588]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: -28, y: 456), Size: (1264, 958, 4)
# lm23: [654, 1227], lm11: [722, 572], lm12: [215, 595]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 0, y: 462), Size: (1237, 937, 4)
# lm23: [659, 1240], lm11: [732, 583], lm12: [235, 598]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 24, y: 473), Size: (1213, 919, 4)
# lm23: [703, 1250], lm11: [781, 598], lm12: [292, 608]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 84, y: 488), Size: (1193, 904, 4)
# lm23: [732, 1260], lm11: [811, 611], lm12: [318, 613]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 108, y: 501), Size: (1204, 912, 4)
# lm23: [794, 1269], lm11: [860, 618], lm12: [357, 625]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 143, y: 508), Size: (1228, 930, 4)
# lm23: [794, 1269], lm11: [880, 631], lm12: [381, 629]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 169, y: 521), Size: (1218, 923, 4)
# lm23: [799, 1268], lm11: [885, 634], lm12: [393, 634]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 184, y: 524), Size: (1201, 910, 4)
# lm23: [798, 1267], lm11: [873, 632], lm12: [383, 638]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 175, y: 522), Size: (1196, 906, 4)
# lm23: [794, 1267], lm11: [868, 630], lm12: [373, 642]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 163, y: 520), Size: (1208, 915, 4)
# lm23: [790, 1262], lm11: [863, 629], lm12: [368, 643]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 158, y: 519), Size: (1208, 915, 4)
# lm23: [787, 1247], lm11: [842, 622], lm12: [364, 642]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 161, y: 512), Size: (1167, 884, 4)
# lm23: [787, 1237], lm11: [823, 611], lm12: [361, 641]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 165, y: 501), Size: (1127, 854, 4)
# lm23: [786, 1224], lm11: [821, 606], lm12: [358, 641]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 161, y: 496), Size: (1130, 856, 4)
# lm23: [781, 1224], lm11: [821, 606], lm12: [356, 640]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 158, y: 496), Size: (1135, 860, 4)
# lm23: [784, 1219], lm11: [821, 606], lm12: [357, 638]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 160, y: 496), Size: (1132, 858, 4)
# lm23: [787, 1219], lm11: [825, 605], lm12: [365, 636]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 170, y: 495), Size: (1123, 851, 4)
# lm23: [800, 1217], lm11: [832, 604], lm12: [384, 633]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 194, y: 494), Size: (1093, 828, 4)
# lm23: [805, 1218], lm11: [838, 604], lm12: [390, 633]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 200, y: 494), Size: (1093, 828, 4)
# lm23: [805, 1219], lm11: [841, 604], lm12: [391, 632]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 200, y: 494), Size: (1098, 832, 4)
# lm23: [804, 1219], lm11: [841, 604], lm12: [392, 630]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 201, y: 494), Size: (1095, 830, 4)
# lm23: [803, 1219], lm11: [844, 606], lm12: [395, 630]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 204, y: 496), Size: (1095, 830, 4)
# lm23: [802, 1224], lm11: [844, 606], lm12: [398, 629]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 209, y: 496), Size: (1089, 825, 4)
# lm23: [803, 1223], lm11: [842, 606], lm12: [402, 627]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 215, y: 496), Size: (1074, 814, 4)
# lm23: [802, 1225], lm11: [843, 606], lm12: [401, 627]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 214, y: 496), Size: (1078, 817, 4)
# lm23: [803, 1223], lm11: [843, 606], lm12: [402, 627]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 215, y: 496), Size: (1076, 815, 4)
# lm23: [805, 1225], lm11: [844, 607], lm12: [403, 626]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 216, y: 497), Size: (1076, 815, 4)
# lm23: [804, 1225], lm11: [844, 607], lm12: [404, 626]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 217, y: 497), Size: (1074, 814, 4)
# lm23: [804, 1226], lm11: [844, 607], lm12: [404, 626]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 217, y: 497), Size: (1074, 814, 4)
# lm23: [803, 1226], lm11: [845, 607], lm12: [403, 626]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 216, y: 497), Size: (1078, 817, 4)
# lm23: [802, 1227], lm11: [845, 608], lm12: [403, 625]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 216, y: 498), Size: (1078, 817, 4)
# lm23: [801, 1228], lm11: [845, 608], lm12: [404, 624]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 217, y: 498), Size: (1076, 815, 4)
# lm23: [801, 1224], lm11: [845, 608], lm12: [404, 624]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 217, y: 498), Size: (1076, 815, 4)
# lm23: [801, 1224], lm11: [842, 608], lm12: [402, 623]
# lm23: [763, 1229], lm11: [827, 605], lm12: [358, 621]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 159, y: 495), Size: (1144, 867, 4)
# lm23: [763, 1229], lm11: [826, 605], lm12: [353, 622]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 152, y: 495), Size: (1155, 875, 4)
# lm23: [763, 1229], lm11: [826, 605], lm12: [355, 622]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 155, y: 495), Size: (1150, 871, 4)
# lm23: [772, 1223], lm11: [826, 605], lm12: [358, 622]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 160, y: 495), Size: (1142, 865, 4)
# lm23: [780, 1222], lm11: [826, 606], lm12: [366, 622]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 171, y: 496), Size: (1123, 851, 4)
# lm23: [776, 1233], lm11: [825, 607], lm12: [350, 628]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 148, y: 497), Size: (1159, 878, 4)
# lm23: [775, 1231], lm11: [826, 603], lm12: [336, 627]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 128, y: 493), Size: (1196, 906, 4)
# lm23: [768, 1223], lm11: [826, 592], lm12: [308, 625]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 88, y: 482), Size: (1264, 958, 4)
# lm23: [712, 1223], lm11: [808, 581], lm12: [269, 597]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 40, y: 471), Size: (1316, 997, 4)
# lm23: [722, 1223], lm11: [809, 566], lm12: [282, 570]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 58, y: 456), Size: (1286, 974, 4)
# lm23: [712, 1175], lm11: [802, 514], lm12: [291, 513]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 74, y: 404), Size: (1247, 945, 4)
# lm23: [710, 1134], lm11: [770, 452], lm12: [269, 471]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 56, y: 342), Size: (1222, 926, 4)
# lm23: [709, 1121], lm11: [752, 418], lm12: [261, 446]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 52, y: 308), Size: (1198, 908, 4)
# lm23: [707, 1102], lm11: [760, 377], lm12: [266, 395]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 57, y: 267), Size: (1205, 913, 4)
# lm23: [708, 1110], lm11: [765, 378], lm12: [268, 391]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 57, y: 268), Size: (1213, 919, 4)
# lm23: [704, 1107], lm11: [766, 366], lm12: [269, 380]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 58, y: 256), Size: (1213, 919, 4)
# lm23: [673, 1114], lm11: [747, 399], lm12: [246, 415]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 33, y: 289), Size: (1222, 926, 4)
# lm23: [663, 1121], lm11: [723, 409], lm12: [226, 425]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 15, y: 299), Size: (1213, 919, 4)
# lm23: [643, 1124], lm11: [702, 419], lm12: [212, 437]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 4, y: 309), Size: (1196, 906, 4)
# lm23: [634, 1150], lm11: [659, 445], lm12: [186, 515]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: -15, y: 335), Size: (1155, 875, 4)
# lm23: [643, 1156], lm11: [641, 475], lm12: [183, 572]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: -11, y: 365), Size: (1118, 847, 4)
# lm23: [647, 1159], lm11: [654, 486], lm12: [190, 573]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: -7, y: 376), Size: (1132, 858, 4)
# lm23: [651, 1154], lm11: [667, 471], lm12: [197, 552]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: -2, y: 361), Size: (1147, 869, 4)
# lm23: [659, 1153], lm11: [688, 457], lm12: [219, 512]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 20, y: 347), Size: (1144, 867, 4)
# lm23: [690, 1142], lm11: [737, 434], lm12: [260, 463]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 57, y: 324), Size: (1164, 882, 4)
# lm23: [720, 1139], lm11: [763, 418], lm12: [272, 443]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 63, y: 308), Size: (1198, 908, 4)
# lm23: [731, 1128], lm11: [764, 394], lm12: [273, 427]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 64, y: 284), Size: (1198, 908, 4)
# lm23: [724, 1118], lm11: [767, 357], lm12: [270, 389]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 59, y: 247), Size: (1213, 919, 4)
# lm23: [720, 1120], lm11: [759, 366], lm12: [222, 398]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: -6, y: 256), Size: (1311, 993, 4)
# lm23: [718, 1121], lm11: [732, 376], lm12: [190, 451]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: -40, y: 266), Size: (1323, 1002, 4)
# lm23: [731, 1094], lm11: [722, 323], lm12: [165, 432]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: -72, y: 213), Size: (1360, 1030, 4)
# lm23: [728, 1066], lm11: [723, 290], lm12: [125, 398]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: -129, y: 180), Size: (1460, 1106, 4)
# lm23: [735, 1010], lm11: [720, 247], lm12: [117, 367]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: -139, y: 137), Size: (1472, 1115, 4)
# lm23: [749, 994], lm11: [720, 224], lm12: [119, 339]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: -136, y: 114), Size: (1467, 1111, 4)
# lm23: [746, 977], lm11: [715, 212], lm12: [128, 323]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: -121, y: 102), Size: (1432, 1085, 4)
# lm23: [744, 970], lm11: [698, 209], lm12: [135, 331]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: -104, y: 99), Size: (1374, 1041, 4)
# lm23: [684, 959], lm11: [631, 228], lm12: [130, 344]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: -83, y: 118), Size: (1222, 926, 4)
# lm23: [671, 919], lm11: [621, 222], lm12: [151, 326]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: -48, y: 112), Size: (1147, 869, 4)
# lm23: [676, 946], lm11: [637, 231], lm12: [225, 335]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 50, y: 121), Size: (1006, 762, 4)
# lm23: [702, 990], lm11: [708, 356], lm12: [324, 396]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 161, y: 246), Size: (937, 710, 4)
# lm23: [729, 1001], lm11: [736, 397], lm12: [361, 432]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 202, y: 287), Size: (915, 693, 4)
# lm23: [740, 1020], lm11: [748, 401], lm12: [357, 443]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 191, y: 291), Size: (954, 723, 4)
# lm23: [732, 1020], lm11: [743, 401], lm12: [352, 444]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 186, y: 291), Size: (954, 723, 4)
# lm23: [727, 1039], lm11: [742, 417], lm12: [346, 452]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 178, y: 307), Size: (966, 732, 4)
# lm23: [728, 1038], lm11: [740, 412], lm12: [347, 448]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 180, y: 302), Size: (959, 727, 4)
# lm23: [722, 1036], lm11: [740, 407], lm12: [345, 444]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 177, y: 297), Size: (963, 730, 4)
# lm23: [722, 1035], lm11: [741, 404], lm12: [343, 442]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 174, y: 294), Size: (971, 736, 4)
# lm23: [718, 1032], lm11: [741, 405], lm12: [346, 440]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 178, y: 295), Size: (963, 730, 4)
# lm23: [716, 1030], lm11: [746, 411], lm12: [350, 440]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 182, y: 301), Size: (966, 732, 4)
# lm23: [739, 995], lm11: [760, 409], lm12: [378, 440]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 216, y: 299), Size: (932, 706, 4)
# lm23: [756, 989], lm11: [773, 407], lm12: [395, 437]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 235, y: 297), Size: (922, 699, 4)
# lm23: [754, 990], lm11: [786, 409], lm12: [407, 437]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 246, y: 299), Size: (925, 701, 4)
# lm23: [755, 991], lm11: [797, 413], lm12: [414, 437]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 251, y: 303), Size: (934, 708, 4)
# lm23: [754, 990], lm11: [804, 412], lm12: [427, 431]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 267, y: 302), Size: (920, 697, 4)
# lm23: [756, 997], lm11: [813, 411], lm12: [434, 428]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 273, y: 301), Size: (925, 701, 4)
# lm23: [767, 1003], lm11: [817, 411], lm12: [438, 431]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 277, y: 301), Size: (925, 701, 4)
# lm23: [767, 1012], lm11: [821, 410], lm12: [445, 433]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 286, y: 300), Size: (917, 695, 4)
# lm23: [772, 1009], lm11: [818, 410], lm12: [444, 437]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 286, y: 300), Size: (912, 691, 4)
# lm23: [775, 1008], lm11: [818, 410], lm12: [451, 438]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 295, y: 300), Size: (895, 678, 4)
# lm23: [778, 1008], lm11: [820, 410], lm12: [448, 439]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 290, y: 300), Size: (908, 688, 4)
# lm23: [777, 1008], lm11: [820, 410], lm12: [447, 439]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 288, y: 300), Size: (911, 690, 4)
# lm23: [776, 995], lm11: [819, 410], lm12: [447, 440]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 289, y: 300), Size: (908, 688, 4)
# lm23: [771, 984], lm11: [814, 410], lm12: [446, 441]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 290, y: 300), Size: (897, 680, 4)
# lm23: [771, 976], lm11: [810, 410], lm12: [444, 442]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 289, y: 300), Size: (893, 677, 4)
# lm23: [761, 955], lm11: [808, 409], lm12: [444, 440]
# Loading shirt image from path: male/formal/10-removebg-preview.png
# Shirt Position: (x: 290, y: 299), Size: (888, 673, 4)
# lm23: [758, 955], lm11: [807, 409], lm12: [443, 440]
# lm23: [748, 732], lm11: [792, 442], lm12: [582, 449]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 493, y: 332), Size: (512, 388, 4)
# lm23: [771, 734], lm11: [813, 448], lm12: [583, 450]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 486, y: 338), Size: (561, 425, 4)
# lm23: [767, 727], lm11: [814, 448], lm12: [583, 449]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 485, y: 338), Size: (563, 427, 4)
# lm23: [757, 721], lm11: [800, 448], lm12: [578, 449]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 484, y: 338), Size: (541, 410, 4)
# lm23: [757, 708], lm11: [801, 447], lm12: [581, 447]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 488, y: 337), Size: (537, 407, 4)
# lm23: [766, 709], lm11: [802, 447], lm12: [580, 447]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 486, y: 337), Size: (541, 410, 4)
# lm23: [776, 716], lm11: [813, 448], lm12: [583, 446]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 486, y: 338), Size: (561, 425, 4)
# lm23: [767, 719], lm11: [816, 449], lm12: [584, 446]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 486, y: 339), Size: (566, 429, 4)
# lm23: [768, 720], lm11: [820, 449], lm12: [586, 446]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 487, y: 339), Size: (570, 432, 4)
# lm23: [767, 721], lm11: [822, 449], lm12: [587, 446]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 487, y: 339), Size: (573, 434, 4)
# lm23: [765, 723], lm11: [821, 450], lm12: [587, 446]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 488, y: 340), Size: (570, 432, 4)
# lm23: [764, 724], lm11: [822, 450], lm12: [588, 445]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 489, y: 340), Size: (570, 432, 4)
# lm23: [768, 724], lm11: [821, 450], lm12: [587, 446]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 488, y: 340), Size: (570, 432, 4)
# lm23: [770, 725], lm11: [823, 450], lm12: [589, 446]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 490, y: 340), Size: (570, 432, 4)
# lm23: [768, 726], lm11: [822, 450], lm12: [590, 446]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 492, y: 340), Size: (566, 429, 4)
# lm23: [769, 726], lm11: [823, 450], lm12: [591, 445]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 493, y: 340), Size: (566, 429, 4)
# lm23: [771, 726], lm11: [823, 451], lm12: [590, 446]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 491, y: 341), Size: (569, 431, 4)
# lm23: [771, 727], lm11: [823, 451], lm12: [590, 446]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 491, y: 341), Size: (569, 431, 4)
# lm23: [771, 727], lm11: [823, 451], lm12: [590, 446]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 491, y: 341), Size: (569, 431, 4)
# lm23: [772, 727], lm11: [822, 451], lm12: [589, 447]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 490, y: 341), Size: (569, 431, 4)
# lm23: [773, 727], lm11: [823, 451], lm12: [589, 447]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 490, y: 341), Size: (570, 432, 4)
# lm23: [774, 727], lm11: [823, 451], lm12: [590, 448]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 491, y: 341), Size: (569, 431, 4)
# lm23: [777, 727], lm11: [823, 451], lm12: [590, 448]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 491, y: 341), Size: (569, 431, 4)
# lm23: [776, 727], lm11: [822, 452], lm12: [590, 449]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 492, y: 342), Size: (566, 429, 4)
# lm23: [776, 727], lm11: [821, 452], lm12: [590, 449]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 492, y: 342), Size: (563, 427, 4)
# lm23: [775, 726], lm11: [820, 453], lm12: [592, 449]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 496, y: 343), Size: (555, 421, 4)
# lm23: [774, 726], lm11: [820, 453], lm12: [593, 449]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 497, y: 343), Size: (553, 419, 4)
# lm23: [774, 726], lm11: [822, 455], lm12: [594, 449]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 498, y: 345), Size: (555, 421, 4)
# lm23: [774, 726], lm11: [823, 455], lm12: [596, 449]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 500, y: 345), Size: (553, 419, 4)
# lm23: [774, 726], lm11: [825, 455], lm12: [598, 448]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 502, y: 345), Size: (553, 419, 4)
# lm23: [774, 724], lm11: [825, 455], lm12: [600, 448]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 504, y: 345), Size: (549, 416, 4)
# lm23: [774, 724], lm11: [826, 455], lm12: [602, 448]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 507, y: 345), Size: (546, 414, 4)
# lm23: [777, 724], lm11: [826, 455], lm12: [603, 448]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 508, y: 345), Size: (544, 412, 4)
# lm23: [779, 723], lm11: [827, 455], lm12: [602, 448]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 506, y: 345), Size: (549, 416, 4)
# lm23: [779, 722], lm11: [826, 455], lm12: [602, 448]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 507, y: 345), Size: (546, 414, 4)
# lm23: [779, 723], lm11: [826, 455], lm12: [601, 448]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 505, y: 345), Size: (549, 416, 4)
# lm23: [779, 724], lm11: [824, 455], lm12: [598, 448]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 502, y: 345), Size: (551, 418, 4)
# lm23: [776, 729], lm11: [820, 455], lm12: [590, 448]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 493, y: 345), Size: (561, 425, 4)
# lm23: [774, 730], lm11: [816, 455], lm12: [581, 450]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 481, y: 345), Size: (573, 434, 4)
# lm23: [768, 734], lm11: [810, 456], lm12: [575, 450]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 475, y: 346), Size: (573, 434, 4)
# lm23: [767, 737], lm11: [807, 456], lm12: [571, 451]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 471, y: 346), Size: (575, 436, 4)
# lm23: [764, 736], lm11: [807, 456], lm12: [571, 451]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 471, y: 346), Size: (575, 436, 4)
# lm23: [763, 765], lm11: [808, 457], lm12: [572, 452]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 472, y: 347), Size: (575, 436, 4)
# lm23: [762, 758], lm11: [808, 458], lm12: [571, 453]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 470, y: 348), Size: (578, 438, 4)
# lm23: [761, 750], lm11: [808, 458], lm12: [572, 453]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 472, y: 348), Size: (575, 436, 4)
# lm23: [761, 740], lm11: [809, 458], lm12: [572, 453]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 471, y: 348), Size: (578, 438, 4)
# lm23: [760, 740], lm11: [809, 459], lm12: [573, 453]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 473, y: 349), Size: (575, 436, 4)
# lm23: [760, 740], lm11: [809, 459], lm12: [573, 453]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 473, y: 349), Size: (575, 436, 4)
# lm23: [760, 738], lm11: [809, 461], lm12: [574, 453]
# Loading shirt image from path: male/formal/11-removebg-preview.png
# Shirt Position: (x: 474, y: 351), Size: (573, 434, 4)
# lm23: [757, 737], lm11: [810, 462], lm12: [574, 452]
# Loading shirt image from path: male/formal/11-removebg-preview.png
